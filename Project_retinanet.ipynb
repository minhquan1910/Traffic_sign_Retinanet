# %% [markdown]
# <a href="https://colab.research.google.com/github/minhquan1910/Traffic_sign_Retinanet/blob/main/Project_retinanet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/fizyr/keras-retinanet.git
# Out:
# Cloning into 'keras-retinanet'...
# remote: Enumerating objects: 6205, done.
# remote: Total 6205 (delta 0), reused 0 (delta 0), pack-reused 6205
# Receiving objects: 100% (6205/6205), 13.47 MiB | 21.58 MiB/s, done.
# Resolving deltas: 100% (4200/4200), done.

# %%
# !git clone https://github.com/minhquan1910/Traffic_sign_Retinanet.git
# Out:
# Cloning into 'Traffic_sign_Retinanet'...
# remote: Enumerating objects: 9, done.
# remote: Counting objects: 100% (9/9), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 9 (delta 1), reused 5 (delta 0), pack-reused 0
# Unpacking objects: 100% (9/9), done.

# %%
#Download dataset from here "https://download1337.mediafire.com/giwlx4ht9qwg/nbge6ccitmjd0th/zalo_tracffic_sign.zip"

# %%
# Class descriptions:
sign_dict = {
    1: "No entry",
    2: "No parking / waiting",
    3: "No turning",
    4: "Max Speed",
    5: "Other prohibition signs",
    6: "Warning",
    7: "Mandatory"
}
#Change your json and image folder to csv file (create a new csv to add)
json_path = 'train_traffic_sign_dataset.json'
csv_path = 'train_traffic_sign_dataset.csv'
with open(csv_path,'w') as csv_file:
  with open(json_path) as json_file:
    data = json.load(json_file)
    annotations = data['annotations']
    for p in annotations:
      print('Bbox: '+ str(p['bbox']))
      print('Image id: ' +str(p['image_id']))
      print('Category_id'+str(sign_dict[p['category_id']]))
      csv_file.write('image/{}.png,{},{},{},{},{}\n'.format(p['image_id'],p['bbox'][0],p['bbox'][1],p['bbox'][0]+p['bbox'][2],p['bbox'][1]+p['bbox'][3],sign_dict[p['category_id']]))
#Make classes.csv (create a new csv to add)
import csv
with open('Classes.csv','w') as file:
  writer = csv.writer(file, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
  for key, val in sign_dict.items():  
    row = [val, key]
    print(row)
    writer.writerow(row)

# %%
#Move to folder keras-retinanet
# %cd keras-retinanet/
# Out:
# /content/keras-retinanet

# %%
#Install the keras-retinanet packet locally on your computer 
# !pip install .
# Out:
# Processing /content/keras-retinanet
# ...
#   Created wheel for keras-retinanet: filename=keras_retinanet-1.0.0-cp37-cp37m-linux_x86_64.whl size=168006 sha256=95096cf925a7ecc270fac2be176be20fe131ccbb95a6b56030d87232cc8f2572
#   Stored in directory: /root/.cache/pip/wheels/b2/9f/57/cb0305f6f5a41fc3c11ad67b8cedfbe9127775b563337827ba
# ...
#   Created wheel for keras-resnet: filename=keras_resnet-0.2.0-py2.py3-none-any.whl size=20486 sha256=23be5613d98bb6bf3389748da4005045bdd568712018747d8708728d7573f4c8
#   Stored in directory: /root/.cache/pip/wheels/5f/09/a5/497a30fd9ad9964e98a1254d1e164bcd1b8a5eda36197ecb3c
# Successfully built keras-retinanet keras-resnet
# ...

# %%
# !python setup.py build_ext --inplace
# Out:
# running build_ext
# cythoning keras_retinanet/utils/compute_overlap.pyx to keras_retinanet/utils/compute_overlap.c
# /usr/local/lib/python3.7/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/keras-retinanet/keras_retinanet/utils/compute_overlap.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'keras_retinanet.utils.compute_overlap' extension
# creating build
# creating build/temp.linux-x86_64-3.7
# creating build/temp.linux-x86_64-3.7/keras_retinanet
# creating build/temp.linux-x86_64-3.7/keras_retinanet/utils
# ...

# %%
#Download tensorflow-gpu (optional)
# !pip install tensorflow-gpu
# Out:
# ...
#      |████████████████████████████████| 394.3MB 44kB/s
# ...

# %%
#--backbone (By default this is set to resnet50 but you can use resnet101,resnet 152)
#--weight (You can use my file .h5 or imagenet .h5 in fizyr github)
#--epochs (By defaulft this is set to 50)
#--batch-size (In this project I choose 8)
#--steps (steps can calculate by number of image divide batchi_zie ex: 4500 imgs / 8)
#After 1 epoch this model will auto save weight file in keras-retinanet/snapshots
#In this project i only train 25 epoch because of my computer
# !keras_retinanet/bin/train.py --freeze-backbone --random-transform --epochs 40 --steps 562 --batch-size 8 csv train_traffic_sign_dataset.csv Classes.csv
# Out:
# 2021-05-02 05:23:28.021223: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Creating model, this may take a second...
# 2021-05-02 05:38:14.369222: I tensorflow/compiler/jit/xla_cpu_device.cc:41] Not creating XLA devices, tf_xla_enable_xla_devices not set
# 2021-05-02 05:38:14.370225: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcuda.so.1
# 2021-05-02 05:38:14.376669: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:941] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-05-02 05:38:14.377290: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1720] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# ...
